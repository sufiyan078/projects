# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/rides.csv')

# %%
df
# Out:
#       Drivers Active Per Hour  Riders Active Per Hour  Rides Completed
# 0                          72                     295            202.0
# 1                          50                      78             43.0
# 2                          40                     250            181.0
# 3                          78                     140            124.0
# 4                          74                     195            108.0
# ...                       ...                     ...              ...
# 1094                       55                     170            144.0
# 1095                       99                     141            117.0
# 1096                       43                      82             64.0
# 1097                       35                     127             90.0
# 1098                       32                      81             60.0
#
# [1099 rows x 3 columns]

# %%
df.shape
# Out:
# (1099, 3)

# %%
df.head(10)
# Out:
#    Drivers Active Per Hour  Riders Active Per Hour  Rides Completed
# 0                       72                     295            202.0
# 1                       50                      78             43.0
# 2                       40                     250            181.0
# 3                       78                     140            124.0
# 4                       74                     195            108.0
# 5                       37                     291            172.0
# 6                       46                      94             79.0
# 7                       97                     280            166.0
# 8                       61                     134             99.0
# 9                       49                     224             51.0

# %%
df.columns
# Out:
# Index(['Drivers Active Per Hour', 'Riders Active Per Hour', 'Rides Completed'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1099 entries, 0 to 1098
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Drivers Active Per Hour  1099 non-null   int64
#  1   Riders Active Per Hour   1099 non-null   int64
#  2   Rides Completed          1045 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 25.9 KB

# %%
df.describe()
# Out:
#        Drivers Active Per Hour  Riders Active Per Hour  Rides Completed
# count              1099.000000             1099.000000      1045.000000
# mean                 55.212921              175.372157       107.470813
# std                  25.896744               72.304222        57.340921
# min                  10.000000               50.000000         2.000000
# 25%                  34.000000              114.000000        66.000000
# 50%                  55.000000              174.000000        96.000000
# 75%                  78.000000              238.000000       142.000000
# max                 100.000000              300.000000       273.000000

# %%
df.isna().sum()
# Out:
# Drivers Active Per Hour     0
# Riders Active Per Hour      0
# Rides Completed            54
# dtype: int64

# %%
df[df['Rides Completed'].isna()]
# Out:
#       Drivers Active Per Hour  Riders Active Per Hour  Rides Completed
# 53                         57                      50              NaN
# 107                        88                      53              NaN
# 109                        86                      66              NaN
# 117                        98                      53              NaN
# 125                        75                      55              NaN
# 174                        92                      81              NaN
# 182                        57                      50              NaN
# 187                        91                      81              NaN
# 203                        90                      69              NaN
# 226                        84                      64              NaN
# 249                        90                      80              NaN
# 304                        70                      62              NaN
# ...

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (1045, 3)

# %%
df.isna().sum()
# Out:
# Drivers Active Per Hour    0
# Riders Active Per Hour     0
# Rides Completed            0
# dtype: int64

# %%
writer = pd.ExcelWriter('demand and supply analysis.xlsx')

# %%
df.to_excel(writer)

# %%
writer.save()
print('DataFrame is written successfully to Excel File.')
# Out:
# DataFrame is written successfully to Excel File.
# <ipython-input-17-a23b5e58f680>:1: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %% [markdown]
# **visiualization is done by tableau tool**

# %% [markdown]
# https://public.tableau.com/views/Demandandsupplyanalysis/Dashboard1?:language=en-GB&publish=yes&:display_count=n&:origin=viz_share_link

# %% [markdown]
# # Summary
#
# Demand and Supply analysis means analyzing the relationship between the quantity demanded and the quantity supplied. It helps businesses understand the factors influencing consumer demand to maximize profits.
