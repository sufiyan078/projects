# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/23_09_2022.csv')

# %%
df.head(10)
# Out:
#                                                 name  offer_price  \
# 0  Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core AMD ...        64890
# 1  Infinix X1 Series Core i7 10th Gen - (16 GB/51...        46890
# 2  ASUS VivoBook K15 OLED Ryzen 7 Octa Core AMD R...        56890
# 3  ASUS Vivobook 15 Ryzen 3 Dual Core AMD R3-3250...        26890
# 4  HP Core i5 12th Gen - (16 GB/512 GB SSD/Window...        57890
# 5  ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...        26990
# 6  ASUS VivoBook 14 (2022) Ryzen 7 Quad Core AMD ...        39901
# 7  Infinix X1 Slim Series Core i5 10th Gen - (8 G...        36890
# 8  Lenovo IdeaPad 3 Ryzen 5 Hexa Core 5500U - (8 ...        43890
# 9  realme Book(Slim) Intel Evo Core i5 11th Gen -...        44890
#
#    original_price  off_now  total_ratings  total_reviews  rating  \
# 0          102090  36% off             15              3     4.3
# 1           69999  33% off            115             17     4.3
# 2           86990  34% off            441             70     4.3
# 3           49990  46% off              0              0     0.0
# 4           72331  19% off            136             18     4.3
# 5           45990  41% off           2759            317     4.3
# 6           70990  43% off            114             12     4.3
# 7           59999  38% off            294             50     4.2
# 8           68490  35% off            660             85     4.3
# 9           69999  35% off           4313            611     4.4
#
#                                          description  \
# 0  ['AMD Ryzen 7 Octa Core Processor', '8 GB DDR4...
# 1  ['Intel Core i7 Processor (10th Gen)', '16 GB ...
# 2  ['AMD Ryzen 7 Octa Core Processor', '16 GB DDR...
# 3  ['AMD Ryzen 3 Dual Core Processor', '8 GB DDR4...
# 4  ['Intel Core i5 Processor (12th Gen)', '16 GB ...
# 5  ['Intel Core i3 Processor (10th Gen)', '8 GB D...
# 6  ['AMD Ryzen 7 Quad Core Processor', '16 GB DDR...
# 7  ['Intel Core i5 Processor (10th Gen)', '8 GB L...
# 8  ['AMD Ryzen 5 Hexa Core Processor', '8 GB DDR4...
# 9  ['Powered by 11th Gen Intel Evo Core i5 Proces...
#
#                          created_at
# 0  2022-09-23 22:43:19.013209+05:30
# 1  2022-09-23 22:43:19.013209+05:30
# 2  2022-09-23 22:43:19.014208+05:30
# 3  2022-09-23 22:43:19.014208+05:30
# 4  2022-09-23 22:43:19.014208+05:30
# 5  2022-09-23 22:43:19.014208+05:30
# 6  2022-09-23 22:43:19.015208+05:30
# 7  2022-09-23 22:43:19.015208+05:30
# 8  2022-09-23 22:43:19.015208+05:30
# 9  2022-09-23 22:43:19.016208+05:30

# %%
df.shape
# Out:
# (936, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            936 non-null    object
#  1   offer_price     936 non-null    int64
#  2   original_price  936 non-null    int64
#  3   off_now         936 non-null    object
#  4   total_ratings   936 non-null    int64
#  5   total_reviews   936 non-null    int64
#  6   rating          936 non-null    float64
#  7   description     936 non-null    object
#  8   created_at      936 non-null    object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 65.9+ KB

# %%
df.describe()
# Out:
#          offer_price  original_price  total_ratings  total_reviews      rating
# count     936.000000      936.000000     936.000000     936.000000  936.000000
# mean    70249.155983    94745.700855     295.676282      40.758547    3.119338
# std     52525.573657    61527.660274    1019.319005     136.423638    1.883983
# min     13990.000000    18890.000000       0.000000       0.000000    0.000000
# 25%     39890.000000    59999.000000       0.000000       0.000000    0.000000
# 50%     49890.000000    69999.000000      32.000000       4.000000    4.200000
# 75%     76135.000000   104890.000000     115.000000      20.000000    4.300000
# max    391890.000000   481990.000000   12850.000000    1390.000000    5.000000

# %%
df.isna().sum()
# Out:
# name              0
# offer_price       0
# original_price    0
# off_now           0
# total_ratings     0
# total_reviews     0
# rating            0
# description       0
# created_at        0
# dtype: int64

# %%
df['name'].value_counts()
# Out:
# Infinix X1 Series Core i7 10th Gen - (16 GB/512 GB SSD/Windows 11 Home/128 MB Graphics) XL12 Thin and ...    73
# Infinix X1 Slim Series Core i5 10th Gen - (16 GB/512 GB SSD/Windows 11 Home) XL21 Thin and Light Lapto...    41
# Infinix X1 Slim Series Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) XL21 Thin and Light Laptop       40
# Infinix X1 Slim Series Core i7 10th Gen - (16 GB/512 GB SSD/Windows 11 Home) XL21 Thin and Light Lapto...    40
# Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core AMD R7-5800H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphic...    37
#                                                                                                              ..
# HP OMEN 15 Ryzen 7 Octa Core AMD R7-5800H - (16 GB/1 TB SSD/Windows 10 Home/8 GB Graphics/NVIDIA GeFor...     1
# DELL Inspiron Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) Inspiron 3501 Laptop                       1
# ASUS VivoBook 15 (2022) Core i5 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) X515EA-EJ502WS T...     1
# Lenovo IdeaPad 3 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) 15IML05 Thin and L...     1
# Lenovo Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15ITL6 Laptop                                     1
# Name: name, Length: 646, dtype: int64

# %%
df['Discount']=df['original_price']-df['offer_price']/df['original_price']*100

# %%
df['Discount']
# Out:
# 0      102026.438437
# 1       69932.013329
# 2       86924.601678
# 3       49936.209242
# 4       72250.965160
#            ...
# 931     64937.629825
# 932     50908.039216
# 933     60821.348112
# 934     84122.415964
# 935     69932.013329
# Name: Discount, Length: 936, dtype: float64

# %%
top_deals = df.sort_values(by="Discount", ascending=False)

# %%
top_deals.head(10)
# Out:
#                                                   name  offer_price  \
# 441  MSI Core i9 12th Gen - (32 GB/2 TB SSD/Windows...       390890
# 370  MSI Core i9 12th Gen - (32 GB/2 TB SSD/Windows...       390890
# 596  ASUS ROG Zephyrus Duo 16 Ryzen 9 Octa Core 690...       391890
# 557  ASUS ROG Zephyrus Duo 16 (2022) with 90Whr Bat...       361890
# 569  ASUS ROG Zephyrus M16 (2022) with 90Whr Batter...       330990
# 776  ASUS ROG Flow Z13 (2022) Core i9 12th Gen - (1...       298990
# 289  ASUS ROG Strix SCAR 15 (2022) Core i9 12th Gen...       300990
# 812  ASUS ROG Flow X13 Ryzen 9 Octa Core 5980HS - (...       224890
# 542  ASUS ROG Flow X13 (2021) Ryzen 9 Octa Core AMD...       229890
# 720  MSI Stealth GS77 Core i7 12th Gen - (32 GB/2 T...       314890
#
#      original_price  off_now  total_ratings  total_reviews  rating  \
# 441          481990  18% off              0              0     0.0
# 370          481990  18% off              0              0     0.0
# 596          467990  16% off              0              0     0.0
# 557          431990  16% off              0              0     0.0
# 569          395990  16% off              0              0     0.0
# 776          383990  22% off              0              0     0.0
# 289          359990  16% off              0              0     0.0
# 812          350990  35% off              0              0     0.0
# 542          350990  34% off              4              0     5.0
# 720          335990   6% off              0              0     0.0
#
#                                            description  \
# 441  ['Intel Core i9 Processor (12th Gen)', '32 GB ...
# 370  ['Intel Core i9 Processor (12th Gen)', '32 GB ...
# 596  ['AMD Ryzen 9 Octa Core Processor', '32 GB DDR...
# 557  ['AMD Ryzen 9 Octa Core Processor', '32 GB DDR...
# 569  ['Intel Core i9 Processor (12th Gen)', '32 GB ...
# 776  ['Intel Core i9 Processor (12th Gen)', '16 GB ...
# 289  ['Intel Core i9 Processor (12th Gen)', '32 GB ...
# 812  ['AMD Ryzen 9 Octa Core Processor', '32 GB LPD...
# 542  ['AMD Ryzen 9 Octa Core Processor', '32 GB LPD...
# 720  ['Intel Core i7 Processor (12th Gen)', '32 GB ...
#
#                            created_at       Discount
# 441  2022-09-23 22:43:34.662489+05:30  481908.900807
# 370  2022-09-23 22:43:31.996818+05:30  481908.900807
# 596  2022-09-23 22:43:40.008076+05:30  467906.261031
# 557  2022-09-23 22:43:39.301365+05:30  431906.227227
# 569  2022-09-23 22:43:39.305364+05:30  395906.414556
# 776  2022-09-23 22:43:46.917972+05:30  383912.135993
# 289  2022-09-23 22:43:29.605488+05:30  359906.389344
# 812  2022-09-23 22:43:47.885955+05:30  350925.926949
# 542  2022-09-23 22:43:38.553964+05:30  350924.502407
# 720  2022-09-23 22:43:45.296849+05:30  335896.279949

# %%
highest_rated = df.sort_values(by="rating", ascending=False)

# %%
highest_rated.head(10)
# Out:
#                                                   name  offer_price  \
# 278  acer Aspire Vero(Green PC ) Core i5 11th Gen -...        53990
# 822  ASUS ExpertBook B9 Core i7 10th Gen - (16 GB/1...        99795
# 188  APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...       309890
# 389  MSI Prestige 14 Evo Intel EVO Core i7 11th Gen...        73990
# 613  ASUS TUF GAMING F15 Core i5 10th Gen - (16 GB/...        63890
# 760  Lenovo Core i3 10th Gen - (4 GB/256 GB SSD/Win...        37790
# 542  ASUS ROG Flow X13 (2021) Ryzen 9 Octa Core AMD...       229890
# 817  HP Spectre x360 Core i5 10th Gen - (8 GB/512 G...       108390
# 741  ASUS Core i3 11th Gen - (4 GB/256 GB SSD/Windo...        39890
# 696  HP OMEN Core i7 11th Gen - (16 GB/1 TB SSD/Win...       118390
#
#      original_price  off_now  total_ratings  total_reviews  rating  \
# 278           65000  16% off              3              1     5.0
# 822          172990  42% off              3              0     5.0
# 188          329900   6% off              9              3     5.0
# 389          106990  30% off              4              0     5.0
# 613           79990  20% off              3              0     5.0
# 760           48900  22% off              1              1     5.0
# 542          350990  34% off              4              0     5.0
# 817          152042  28% off              2              1     5.0
# 741           52990  24% off              2              1     5.0
# 696          138399  14% off              2              1     5.0
#
#                                            description  \
# 278  ['Intel Core i5 Processor (11th Gen)', '8 GB D...
# 822  ['Intel Core i7 Processor (10th Gen)', '16 GB ...
# 188  ['Apple M1 Max Processor', '32 GB Unified Memo...
# 389  ['Intel Core i7 Processor (11th Gen)', '16 GB ...
# 613  ['Intel Core i5 Processor (10th Gen)', '16 GB ...
# 760  ['Intel Core i3 Processor (10th Gen)', '4 GB D...
# 542  ['AMD Ryzen 9 Octa Core Processor', '32 GB LPD...
# 817  ['Intel Core i5 Processor (10th Gen)', '8 GB D...
# 741  ['Intel Core i3 Processor (11th Gen)', '4 GB D...
# 696  ['Intel Core i7 Processor (11th Gen)', '16 GB ...
#
#                            created_at       Discount
# 278  2022-09-23 22:43:28.708512+05:30   64916.938462
# 822  2022-09-23 22:43:48.762304+05:30  172932.311694
# 188  2022-09-23 22:43:25.528662+05:30  329806.065474
# 389  2022-09-23 22:43:32.945318+05:30  106920.844004
# 613  2022-09-23 22:43:40.987196+05:30   79910.127516
# 760  2022-09-23 22:43:46.034645+05:30   48822.719836
# 542  2022-09-23 22:43:38.553964+05:30  350924.502407
# 817  2022-09-23 22:43:48.761303+05:30  151970.710488
# 741  2022-09-23 22:43:45.302849+05:30   52914.721646
# 696  2022-09-23 22:43:44.202331+05:30  138313.457474

# %%
most_expensive = df.sort_values(by="offer_price", ascending=False)

# %%
most_expensive.head(10)
# Out:
#                                                   name  offer_price  \
# 596  ASUS ROG Zephyrus Duo 16 Ryzen 9 Octa Core 690...       391890
# 370  MSI Core i9 12th Gen - (32 GB/2 TB SSD/Windows...       390890
# 441  MSI Core i9 12th Gen - (32 GB/2 TB SSD/Windows...       390890
# 557  ASUS ROG Zephyrus Duo 16 (2022) with 90Whr Bat...       361890
# 569  ASUS ROG Zephyrus M16 (2022) with 90Whr Batter...       330990
# 720  MSI Stealth GS77 Core i7 12th Gen - (32 GB/2 T...       314890
# 188  APPLE 2021 Macbook Pro M1 Max - (32 GB/1 TB SS...       309890
# 289  ASUS ROG Strix SCAR 15 (2022) Core i9 12th Gen...       300990
# 776  ASUS ROG Flow Z13 (2022) Core i9 12th Gen - (1...       298990
# 737  MSI Stealth GS66 Core i7 12th Gen - (32 GB/1 T...       285890
#
#      original_price  off_now  total_ratings  total_reviews  rating  \
# 596          467990  16% off              0              0     0.0
# 370          481990  18% off              0              0     0.0
# 441          481990  18% off              0              0     0.0
# 557          431990  16% off              0              0     0.0
# 569          395990  16% off              0              0     0.0
# 720          335990   6% off              0              0     0.0
# 188          329900   6% off              9              3     5.0
# 289          359990  16% off              0              0     0.0
# 776          383990  22% off              0              0     0.0
# 737          313990   8% off              0              0     0.0
#
#                                            description  \
# 596  ['AMD Ryzen 9 Octa Core Processor', '32 GB DDR...
# 370  ['Intel Core i9 Processor (12th Gen)', '32 GB ...
# 441  ['Intel Core i9 Processor (12th Gen)', '32 GB ...
# 557  ['AMD Ryzen 9 Octa Core Processor', '32 GB DDR...
# 569  ['Intel Core i9 Processor (12th Gen)', '32 GB ...
# 720  ['Intel Core i7 Processor (12th Gen)', '32 GB ...
# 188  ['Apple M1 Max Processor', '32 GB Unified Memo...
# 289  ['Intel Core i9 Processor (12th Gen)', '32 GB ...
# 776  ['Intel Core i9 Processor (12th Gen)', '16 GB ...
# 737  ['Intel Core i7 Processor (12th Gen)', '32 GB ...
#
#                            created_at       Discount
# 596  2022-09-23 22:43:40.008076+05:30  467906.261031
# 370  2022-09-23 22:43:31.996818+05:30  481908.900807
# 441  2022-09-23 22:43:34.662489+05:30  481908.900807
# 557  2022-09-23 22:43:39.301365+05:30  431906.227227
# 569  2022-09-23 22:43:39.305364+05:30  395906.414556
# 720  2022-09-23 22:43:45.296849+05:30  335896.279949
# 188  2022-09-23 22:43:25.528662+05:30  329806.065474
# 289  2022-09-23 22:43:29.605488+05:30  359906.389344
# 776  2022-09-23 22:43:46.917972+05:30  383912.135993
# 737  2022-09-23 22:43:45.301849+05:30  313898.949330

# %% [markdown]
# # Visiualization

# %% [markdown]
# ![image.png](data:image/png;base64,...)
