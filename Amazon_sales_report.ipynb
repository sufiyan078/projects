# %%
import numpy as np
import pandas as pd

# %%
import zipfile
with zipfile.ZipFile('/content/Amazon Sale Report.csv.zip') as zip_file:
    file_list = zip_file.namelist()

file_list
# Out:
# ['Amazon Sale Report.csv']

# %%
import pandas as pd
with zipfile.ZipFile('/content/Amazon Sale Report.csv.zip') as zip_file:
    df = pd.read_csv(zip_file.open('Amazon Sale Report.csv'))
# Out:
# <ipython-input-7-1383b2c280e1>:3: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zip_file.open('Amazon Sale Report.csv'))

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
writer = pd.ExcelWriter('Amazon sales report.xlsx')

# %%
df.to_excel(writer)

# %%
writer.save()
print('DataFrame is written successfully to Excel File.')
# Out:
# <ipython-input-11-a23b5e58f680>:1: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
# DataFrame is written successfully to Excel File.

# %% [markdown]
# ## **Visiualization**

# %% [markdown]
# https://public.tableau.com/views/AmazonSalesinIndia_16845014745210/Dashboard1?:language=en-GB&publish=yes&:display_count=n&:origin=viz_share_link
