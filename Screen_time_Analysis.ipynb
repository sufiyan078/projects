# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/Screentime-App-Details.csv')

# %%
df.head(10)
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram
# 5  08/31/2022     19             25            20  Instagram
# 6  09/01/2022     44             23            57  Instagram
# 7  09/02/2022     16             28            22  Instagram
# 8  09/03/2022     27             15            25  Instagram
# 9  09/04/2022     72             29            30  Instagram

# %%
df.shape
# Out:
# (54, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           54 non-null     object
#  1   Usage          54 non-null     int64
#  2   Notifications  54 non-null     int64
#  3   Times opened   54 non-null     int64
#  4   App            54 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#             Usage  Notifications  Times opened
# count   54.000000      54.000000     54.000000
# mean    65.037037     117.703704     61.481481
# std     58.317272      97.017530     43.836635
# min      1.000000       8.000000      2.000000
# 25%     17.500000      25.750000     23.500000
# 50%     58.500000      99.000000     62.500000
# 75%     90.500000     188.250000     90.000000
# max    244.000000     405.000000    192.000000

# %%
df.isna().sum()
# Out:
# Date             0
# Usage            0
# Notifications    0
# Times opened     0
# App              0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Now let’s start with analyzing the screen time of the user. I will first look at the amount of usage of the apps:

# %%
x=df['Date']
y=df['Usage']
plt.bar(x,y)
plt.show()

# %% [markdown]
# For Better understanding we will be using Tableau visiualization tool

# %% [markdown]
# https://public.tableau.com/views/ScreenTimeAnalysis_16858022510630/Dashboard1?:language=en-GB&publish=yes&:display_count=n&:origin=viz_share_link
#
#
#
# Above link is the visiualization of the data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Summary**
#
# So this is how we can analyze the screen time of a user using the Python programming language. Screen Time Analysis is the task of analyzing and creating a report on which applications and websites are used by the user for how much time.
